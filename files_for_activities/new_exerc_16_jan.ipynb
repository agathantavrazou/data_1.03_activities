# %%
import pandas as pd

# %%
file3 = pd.read_excel('file3.xlsx')

# %%
file4 = pd.read_excel('file4.xlsx')

# %%
file3.columns
# Out:
# Index(['CONTROLN', 'STATE', 'GENDER', 'HV1', 'IC1', 'IC4', 'HVP1', 'IC5',
#        'POBC1', 'POBC2', 'IC2', 'IC3', 'AVGGIFT', 'TCODE', 'DOB', 'DOMAIN',
#        'TARGET_D'],
#       dtype='object')

# %%
file4.columns
# Out:
# Index(['CONTROLN', 'STATE', 'GENDER', 'HV1', 'IC1', 'IC4', 'HVP1', 'IC5',
#        'POBC1', 'POBC2', 'IC2', 'IC3', 'AVGGIFT', 'TCODE', 'DOB', 'DOMAIN',
#        'TARGET_D'],
#       dtype='object')

# %%
file3 = file3.rename(columns={ 'controln':'id','hv1':'median_home_val', 'ic1':'median_household_income'})
file4 = file4.rename(columns={ 'controln':'id','hv1':'median_home_val', 'ic1':'median_household_income'})

# %%
cols1=[]
for c in file3.columns:
    cols1.append(c.lower())

file3.columns=cols1

# Similarly for the other dataframe:
cols2=[]
for c in file4.columns:
    cols2.append(c.lower())

file4.columns=cols2

# %%
file3
# Out:
#      controln      state  gender   hv1  ic1  ic4  hvp1    ic5  pobc1  pobc2  \
# 0      119966         TX       F   321  225  281     0   9372      3     68
# 1      152470         CA       F  5725  610  807    97  53158     13     22
# 2       48527         AL    Male   931  407  496     0  17743      0     65
# 3      171528         CA       F  1895  317  471    46  17431     10     62
# 4       50122  Tennessee       F   715  318  370     2  12416      0     75
# ..        ...        ...     ...   ...  ...  ...   ...    ...    ...    ...
# 995    179863         WA    male  1253  325  447     7  15635     12     57
# 996     87395         MT  female   842  264  388     3  15084      2     50
# 997     86779         ND       F   331  165  266     0   9324      1     61
# 998     25214         NC  female  1823  544  567    43  21265      1     62
# 999     79641         WI       F  1244  672  776    25  25036      1     64
#
#      ic2  ic3    avggift  tcode   dob domain  target_d
# 0    264  243   8.058824      0  3212     T3      11.0
# 1    763  698  23.727273      0     0     S1      45.0
# 2    502  439   4.416667      2     0     R3       3.0
# 3    389  405   6.705882      0  5501     R2       5.0
# 4    340  352   9.250000      2     0     T1      10.0
# ..   ...  ...        ...    ...   ...    ...       ...
# 995  454  374   9.187500      1  4702     U1      10.0
# 996  286  370  15.100000      0  1701     R1      20.0
# 997  172  232  10.666667     28     0     T3      11.0
# 998  552  552  12.000000     28  5111     T1      25.0
# 999  713  743   9.937500      0  2310     S1      12.0
#
# [1000 rows x 17 columns]

# %%
file4
# Out:
#       controln state gender      hv1  ic1  ic4  hvp1    ic5  pobc1  pobc2  \
# 0       186307    CA      M  AAA1229  345  438     3  15915      2     58
# 1        34174    WV      F      529  198  291     0  10816      0     80
# 2       101388    MO      M      526  340  342     0   9687      0     89
# 3       159472    CA      F      621  231  279     0   6184     43     41
# 4       179143    WA   male     1688  496  564    35  22963      2     63
# ...        ...   ...    ...      ...  ...  ...   ...    ...    ...    ...
# 1001     41537    FL      F      742  396  470     0  15356      7     37
# 1002      4881    FL      M      599  100  423     4  11670     10     27
# 1003     66358    ND      M      593  258  299     0  10186      1     70
# 1004      2231    WI   male      564  217  397     0  12315      0     96
# 1005     68534    MI      M      651  431  505     0  14845      7     77
#
#       ic2  ic3    avggift  tcode   dob domain  target_d
# 0     388  417  16.142857      1  2511     C2      20.0
# 1     218  257   6.083333      2  3001     T2      12.0
# 2     348  321   5.800000      1  5501     R2      10.0
# 3     237  272  11.666667      1  1512     R3      15.0
# 4     520  521  23.900000      1  3709     T1      25.0
# ...   ...  ...        ...    ...   ...    ...       ...
# 1001  424  450  14.285714      2  6101     S2      50.0
# 1002  406  200   9.230769     28  7401     C1      10.0
# 1003  298  274   5.266667      1  3301     S2       5.0
# 1004  386  295  11.400000      1  7301     T2      14.0
# 1005  451  455   7.428571      1  1709     S2       9.0
#
# [1006 rows x 17 columns]

# %%
file3 = file3.rename(columns={ 'controln':'id','hv1':'median_home_val', 'ic1':'median_household_income'})
file4 = file4.rename(columns={ 'controln':'id','hv1':'median_home_val', 'ic1':'median_household_income'})

# %%
data = pd.concat([file3, file4])
data
# Out:
#           id      state gender median_home_val  median_household_income  ic4  \
# 0     119966         TX      F             321                      225  281
# 1     152470         CA      F            5725                      610  807
# 2      48527         AL   Male             931                      407  496
# 3     171528         CA      F            1895                      317  471
# 4      50122  Tennessee      F             715                      318  370
# ...      ...        ...    ...             ...                      ...  ...
# 1001   41537         FL      F             742                      396  470
# 1002    4881         FL      M             599                      100  423
# 1003   66358         ND      M             593                      258  299
# 1004    2231         WI   male             564                      217  397
# 1005   68534         MI      M             651                      431  505
#
#       hvp1    ic5  pobc1  pobc2  ic2  ic3    avggift  tcode   dob domain  \
# 0        0   9372      3     68  264  243   8.058824      0  3212     T3
# 1       97  53158     13     22  763  698  23.727273      0     0     S1
# 2        0  17743      0     65  502  439   4.416667      2     0     R3
# 3       46  17431     10     62  389  405   6.705882      0  5501     R2
# 4        2  12416      0     75  340  352   9.250000      2     0     T1
# ...    ...    ...    ...    ...  ...  ...        ...    ...   ...    ...
# 1001     0  15356      7     37  424  450  14.285714      2  6101     S2
# 1002     4  11670     10     27  406  200   9.230769     28  7401     C1
# 1003     0  10186      1     70  298  274   5.266667      1  3301     S2
# 1004     0  12315      0     96  386  295  11.400000      1  7301     T2
# 1005     0  14845      7     77  451  455   7.428571      1  1709     S2
#
#       target_d
# 0         11.0
# 1         45.0
# 2          3.0
# 3          5.0
# 4         10.0
# ...        ...
# 1001      50.0
# 1002      10.0
# 1003       5.0
# 1004      14.0
# 1005       9.0
#
# [2006 rows x 17 columns]

# %%
data.columns
# Out:
# Index(['controln', 'state', 'gender', 'hv1', 'ic1', 'ic4', 'hvp1', 'ic5',
#        'pobc1', 'pobc2', 'ic2', 'ic3', 'avggift', 'tcode', 'dob', 'domain',
#        'target_d'],
#       dtype='object')

# %%
data = data.drop(columns=['domain','dob']) #axis
# Out:
# -----------------------------------------
# KeyErrorTraceback (most recent call last)
# <ipython-input-56-73b6021ef59a> in <module>
# ----> 1 data = data.drop(columns=['domain','dob']) #axis
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4161                 weight  1.0     0.8
#    4162         """
# -> 4163         return super().drop(
#    4164             labels=labels,
#    4165             axis=axis,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3885         for axis, labels in axes.items():
#    3886             if labels is not None:
# -> 3887                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3888
#    3889         if inplace:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    3919                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3920             else:
# -> 3921                 new_axis = axis.drop(labels, errors=errors)
#    3922             result = self.reindex(**{axis_name: new_axis})
#    3923
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    5280         if mask.any():
#    5281             if errors != "ignore":
# -> 5282                 raise KeyError(f"{labels[mask]} not found in axis")
#    5283             indexer = indexer[~mask]
#    5284         return self.delete(indexer)
#
# KeyError: "['domain' 'dob'] not found in axis"

# %%
data.columns
# Out:
# Index(['id', 'state', 'gender', 'median_home_val', 'median_household_income',
#        'ic4', 'hvp1', 'ic5', 'pobc1', 'pobc2', 'ic2', 'ic3', 'avggift',
#        'tcode', 'dob', 'domain', 'target_d'],
#       dtype='object')

# %%
data = data[['id', 'state', 'gender', 'ic2', 'ic3', 'ic4', 'ic5', 'median_home_val', 'median_household_income',
        'hvp1', 'pobc1', 'pobc2',  'avggift',
       'tcode', 'dob', 'domain', 'target_d']]

data
# Out:
#           id      state gender  ic2  ic3  ic4    ic5 median_home_val  \
# 0     119966         TX      F  264  243  281   9372             321
# 1     152470         CA      F  763  698  807  53158            5725
# 2      48527         AL   Male  502  439  496  17743             931
# 3     171528         CA      F  389  405  471  17431            1895
# 4      50122  Tennessee      F  340  352  370  12416             715
# ...      ...        ...    ...  ...  ...  ...    ...             ...
# 1001   41537         FL      F  424  450  470  15356             742
# 1002    4881         FL      M  406  200  423  11670             599
# 1003   66358         ND      M  298  274  299  10186             593
# 1004    2231         WI   male  386  295  397  12315             564
# 1005   68534         MI      M  451  455  505  14845             651
#
#       median_household_income  hvp1  pobc1  pobc2    avggift  tcode   dob  \
# 0                         225     0      3     68   8.058824      0  3212
# 1                         610    97     13     22  23.727273      0     0
# 2                         407     0      0     65   4.416667      2     0
# 3                         317    46     10     62   6.705882      0  5501
# 4                         318     2      0     75   9.250000      2     0
# ...                       ...   ...    ...    ...        ...    ...   ...
# 1001                      396     0      7     37  14.285714      2  6101
# 1002                      100     4     10     27   9.230769     28  7401
# 1003                      258     0      1     70   5.266667      1  3301
# 1004                      217     0      0     96  11.400000      1  7301
# 1005                      431     0      7     77   7.428571      1  1709
#
#      domain  target_d
# 0        T3      11.0
# 1        S1      45.0
# 2        R3       3.0
# 3        R2       5.0
# 4        T1      10.0
# ...     ...       ...
# 1001     S2      50.0
# 1002     C1      10.0
# 1003     S2       5.0
# 1004     T2      14.0
# 1005     S2       9.0
#
# [2006 rows x 17 columns]

# %%
condition = data[(data['gender']=='M') & (data['state']=="FL")]
condition
# Out:
#          id state gender  ic2  ic3  ic4    ic5 median_home_val  \
# 30    35581    FL      M  377  360  473  16729             906
# 31    46358    FL      M  371  388  408  12806             715
# 38    41545    FL      M  392  417  436  14942             658
# 55    11284    FL      M  391  404  478  17408             934
# 59    25678    FL      M  339  335  365  12474             721
# ...     ...   ...    ...  ...  ...  ...    ...             ...
# 962   36776    FL      M  360  358  379  12869             653
# 973    4881    FL      M  406  200  423  11670             599
# 992    6403    FL      M  272  324  313  12509             677
# 997    6443    FL      M  263  262  274  11132             595
# 1002   4881    FL      M  406  200  423  11670             599
#
#       median_household_income  hvp1  pobc1  pobc2    avggift  tcode   dob  \
# 30                        296     3      4     37  10.428571      1  2812
# 31                        362     0      6     28   7.466667      1  1801
# 38                        373     0     11     23   5.789474      1     0
# 55                        324     9      4     11   6.366667      0  3201
# 59                        302     2      3     51   8.875000      1     0
# ...                       ...   ...    ...    ...        ...    ...   ...
# 962                       319     0     11     35   9.500000      1  2601
# 973                       100     4     10     27   9.230769     28  7401
# 992                       311     0      2     23  10.115385      1  2703
# 997                       252     0      8     11  14.692308      1  2501
# 1002                      100     4     10     27   9.230769     28  7401
#
#      domain  target_d
# 30       S1      15.0
# 31       T2       9.0
# 38       S2       5.0
# 55       C2       4.0
# 59       C1      20.0
# ...     ...       ...
# 962      S3      20.0
# 973      C1      10.0
# 992      C2      10.0
# 997      T2      20.0
# 1002     C1      10.0
#
# [69 rows x 17 columns]

# %%
filtered = data[(data['target_d']<=100) & (data['gender']=='F')]
data
# Out:
#           id      state gender  ic2  ic3  ic4    ic5 median_home_val  \
# 0     119966         TX      F  264  243  281   9372             321
# 1     152470         CA      F  763  698  807  53158            5725
# 2      48527         AL   Male  502  439  496  17743             931
# 3     171528         CA      F  389  405  471  17431            1895
# 4      50122  Tennessee      F  340  352  370  12416             715
# ...      ...        ...    ...  ...  ...  ...    ...             ...
# 1001   41537         FL      F  424  450  470  15356             742
# 1002    4881         FL      M  406  200  423  11670             599
# 1003   66358         ND      M  298  274  299  10186             593
# 1004    2231         WI   male  386  295  397  12315             564
# 1005   68534         MI      M  451  455  505  14845             651
#
#       median_household_income  hvp1  pobc1  pobc2    avggift  tcode   dob  \
# 0                         225     0      3     68   8.058824      0  3212
# 1                         610    97     13     22  23.727273      0     0
# 2                         407     0      0     65   4.416667      2     0
# 3                         317    46     10     62   6.705882      0  5501
# 4                         318     2      0     75   9.250000      2     0
# ...                       ...   ...    ...    ...        ...    ...   ...
# 1001                      396     0      7     37  14.285714      2  6101
# 1002                      100     4     10     27   9.230769     28  7401
# 1003                      258     0      1     70   5.266667      1  3301
# 1004                      217     0      0     96  11.400000      1  7301
# 1005                      431     0      7     77   7.428571      1  1709
#
#      domain  target_d
# 0        T3      11.0
# 1        S1      45.0
# 2        R3       3.0
# 3        R2       5.0
# 4        T1      10.0
# ...     ...       ...
# 1001     S2      50.0
# 1002     C1      10.0
# 1003     S2       5.0
# 1004     T2      14.0
# 1005     S2       9.0
#
# [2006 rows x 17 columns]

# %%
filtered2 = data[data['gender']=='F']
filtered2
# Out:
#           id      state gender  ic2  ic3  ic4    ic5 median_home_val  \
# 0     119966         TX      F  264  243  281   9372             321
# 1     152470         CA      F  763  698  807  53158            5725
# 3     171528         CA      F  389  405  471  17431            1895
# 4      50122  Tennessee      F  340  352  370  12416             715
# 5      92293         IL      F  897  934  973  35266            3359
# ...      ...        ...    ...  ...  ...  ...    ...             ...
# 991    77441         WI      F  354  335  376  11623             725
# 993   117326         TX      F  750  626  837  31480            1715
# 996    66762         MI      F  336  339  388  12653             632
# 998   151175         CA      F  504  538  537  16165            2707
# 1001   41537         FL      F  424  450  470  15356             742
#
#       median_household_income  hvp1  pobc1  pobc2    avggift  tcode   dob  \
# 0                         225     0      3     68   8.058824      0  3212
# 1                         610    97     13     22  23.727273      0     0
# 3                         317    46     10     62   6.705882      0  5501
# 4                         318     2      0     75   9.250000      2     0
# 5                         878    87     16     74   5.800000      0  2201
# ...                       ...   ...    ...    ...        ...    ...   ...
# 991                       316     0      1     86   7.666667      0  5701
# 993                       554    34      3     54   6.916667      0  4105
# 996                       279     2      1     71   8.533333      0     0
# 998                       507    80     24     54  12.117647      0  4001
# 1001                      396     0      7     37  14.285714      2  6101
#
#      domain  target_d
# 0        T3      11.0
# 1        S1      45.0
# 3        R2       5.0
# 4        T1      10.0
# 5        S1       5.0
# ...     ...       ...
# 991      T2       7.0
# 993      U1      10.0
# 996       0       5.0
# 998      U1      22.0
# 1001     S2      50.0
#
# [984 rows x 17 columns]

# %%
data[0:9]
data.head(10
# Out:
#        id      state gender  ic2  ic3  ic4    ic5 median_home_val  \
# 0  119966         TX      F  264  243  281   9372             321
# 1  152470         CA      F  763  698  807  53158            5725
# 2   48527         AL   Male  502  439  496  17743             931
# 3  171528         CA      F  389  405  471  17431            1895
# 4   50122  Tennessee      F  340  352  370  12416             715
# 5   92293         IL      F  897  934  973  35266            3359
# 6   47191         AL      F  295  330  378  20090             950
# 7   89288         IL      F  467  464  507  15884            1243
# 8  101676         MO      M  560  571  612  18860            1162
# 9   30051         GA      F  260  250  292   9279             359
#
#    median_household_income  hvp1  pobc1  pobc2    avggift  tcode   dob domain  \
# 0                      225     0      3     68   8.058824      0  3212     T3
# 1                      610    97     13     22  23.727273      0     0     S1
# 2                      407     0      0     65   4.416667      2     0     R3
# 3                      317    46     10     62   6.705882      0  5501     R2
# 4                      318     2      0     75   9.250000      2     0     T1
# 5                      878    87     16     74   5.800000      0  2201     S1
# 6                      264     3      6     55   4.142857      2  2601     C1
# 7                      414     9     18     70  10.400000      0  5308     S2
# 8                      529     7      4     60  10.125000      1  3405     C1
# 9                      205     0      0     90   9.000000      0  4501      0
#
#    target_d
# 0      11.0
# 1      45.0
# 2       3.0
# 3       5.0
# 4      10.0
# 5       5.0
# 6       5.0
# 7      15.0
# 8      15.0
# 9      10.0

# %%
filtered2 = filtered2.reset_index(drop=True)
filtered2
# Out:
#          id      state gender  ic2  ic3  ic4    ic5 median_home_val  \
# 0    119966         TX      F  264  243  281   9372             321
# 1    152470         CA      F  763  698  807  53158            5725
# 2    171528         CA      F  389  405  471  17431            1895
# 3     50122  Tennessee      F  340  352  370  12416             715
# 4     92293         IL      F  897  934  973  35266            3359
# ..      ...        ...    ...  ...  ...  ...    ...             ...
# 979   77441         WI      F  354  335  376  11623             725
# 980  117326         TX      F  750  626  837  31480            1715
# 981   66762         MI      F  336  339  388  12653             632
# 982  151175         CA      F  504  538  537  16165            2707
# 983   41537         FL      F  424  450  470  15356             742
#
#      median_household_income  hvp1  pobc1  pobc2    avggift  tcode   dob  \
# 0                        225     0      3     68   8.058824      0  3212
# 1                        610    97     13     22  23.727273      0     0
# 2                        317    46     10     62   6.705882      0  5501
# 3                        318     2      0     75   9.250000      2     0
# 4                        878    87     16     74   5.800000      0  2201
# ..                       ...   ...    ...    ...        ...    ...   ...
# 979                      316     0      1     86   7.666667      0  5701
# 980                      554    34      3     54   6.916667      0  4105
# 981                      279     2      1     71   8.533333      0     0
# 982                      507    80     24     54  12.117647      0  4001
# 983                      396     0      7     37  14.285714      2  6101
#
#     domain  target_d
# 0       T3      11.0
# 1       S1      45.0
# 2       R2       5.0
# 3       T1      10.0
# 4       S1       5.0
# ..     ...       ...
# 979     T2       7.0
# 980     U1      10.0
# 981      0       5.0
# 982     U1      22.0
# 983     S2      50.0
#
# [984 rows x 17 columns]

# %%
filtered2.iloc[100:200]
# Out:
#          id state gender  ic2  ic3  ic4    ic5 median_home_val  \
# 100   35908    FL      F  457  413  463  16854             693
# 101   81073    WI      F  307  295  349  13144             571
# 102   38471    FL      F  545  544  598  22327            1033
# 103   95536    IL      F  465  447  433  13887             886
# 104  103330    MO      F  432  445  492  16206             915
# ..      ...   ...    ...  ...  ...  ...    ...             ...
# 195   90566    IL      F  424  444  449  13716            1181
# 196  186013    AL      F  316  351  391  12774             554
# 197   95132    IL      F  329  295  357  12842             512
# 198  130926    CO      F  568  565  599  18850            1175
# 199  114912    OK      F  338  316  345  10625             622
#
#      median_household_income  hvp1  pobc1  pobc2    avggift  tcode   dob  \
# 100                      373     7      1     24  15.000000      0  5001
# 101                      243     0      3     74   9.166667      2  4701
# 102                      471    25      6     36  13.777778      2  5001
# 103                      482     3      0     68  16.666667     28  4601
# 104                      377     7      3     62  10.333333      0  4508
# ..                       ...   ...    ...    ...        ...    ...   ...
# 195                      417     0      2     69   8.428571      0  5703
# 196                      296     4      1     63   9.500000      0  2002
# 197                      269     1      1     73  14.000000      0  1601
# 198                      517     8      2     38   5.222222      0  3001
# 199                      306     0      0     64  16.653846      2     0
#
#     domain  target_d
# 100     S2      20.0
# 101     C2      10.0
# 102      0      25.0
# 103     T2      20.0
# 104     T1      50.0
# ..     ...       ...
# 195     C2      15.0
# 196     T2      15.0
# 197     R2      25.0
# 198     T1       5.0
# 199     T2      25.0
#
# [100 rows x 17 columns]

# %%
filtered2.iloc[:100, 2:6]
# Out:
#    gender  ic2  ic3  ic4
# 0       F  264  243  281
# 1       F  763  698  807
# 2       F  389  405  471
# 3       F  340  352  370
# 4       F  897  934  973
# ..    ...  ...  ...  ...
# 95      F  171  263  220
# 96      F  289  313  352
# 97      F  249  276  301
# 98      F  282  309  329
# 99      F  225  233  287
#
# [100 rows x 4 columns]

# %%
data.dtypes
# Out:
# id                           int64
# state                       object
# gender                      object
# ic2                          int64
# ic3                          int64
# ic4                          int64
# ic5                          int64
# median_home_val             object
# median_household_income      int64
# hvp1                         int64
# pobc1                        int64
# pobc2                        int64
# avggift                    float64
# tcode                        int64
# dob                          int64
# domain                      object
# target_d                   float64
# dtype: object

# %%
data.select_dtypes(include=['int64','float64'])
# Out:
#           id  ic2  ic3  ic4    ic5  median_household_income  hvp1  pobc1  \
# 0     119966  264  243  281   9372                      225     0      3
# 1     152470  763  698  807  53158                      610    97     13
# 2      48527  502  439  496  17743                      407     0      0
# 3     171528  389  405  471  17431                      317    46     10
# 4      50122  340  352  370  12416                      318     2      0
# ...      ...  ...  ...  ...    ...                      ...   ...    ...
# 1001   41537  424  450  470  15356                      396     0      7
# 1002    4881  406  200  423  11670                      100     4     10
# 1003   66358  298  274  299  10186                      258     0      1
# 1004    2231  386  295  397  12315                      217     0      0
# 1005   68534  451  455  505  14845                      431     0      7
#
#       pobc2    avggift  tcode   dob  target_d
# 0        68   8.058824      0  3212      11.0
# 1        22  23.727273      0     0      45.0
# 2        65   4.416667      2     0       3.0
# 3        62   6.705882      0  5501       5.0
# 4        75   9.250000      2     0      10.0
# ...     ...        ...    ...   ...       ...
# 1001     37  14.285714      2  6101      50.0
# 1002     27   9.230769     28  7401      10.0
# 1003     70   5.266667      1  3301       5.0
# 1004     96  11.400000      1  7301      14.0
# 1005     77   7.428571      1  1709       9.0
#
# [2006 rows x 13 columns]

# %%
data['median_home_val'] = pd.to_numeric(data['median_home_val'], errors='coerce')
data
# Out:
#           id      state gender  ic2  ic3  ic4    ic5  median_home_val  \
# 0     119966         TX      F  264  243  281   9372            321.0
# 1     152470         CA      F  763  698  807  53158           5725.0
# 2      48527         AL   Male  502  439  496  17743            931.0
# 3     171528         CA      F  389  405  471  17431           1895.0
# 4      50122  Tennessee      F  340  352  370  12416            715.0
# ...      ...        ...    ...  ...  ...  ...    ...              ...
# 1001   41537         FL      F  424  450  470  15356            742.0
# 1002    4881         FL      M  406  200  423  11670            599.0
# 1003   66358         ND      M  298  274  299  10186            593.0
# 1004    2231         WI   male  386  295  397  12315            564.0
# 1005   68534         MI      M  451  455  505  14845            651.0
#
#       median_household_income  hvp1  pobc1  pobc2    avggift  tcode   dob  \
# 0                         225     0      3     68   8.058824      0  3212
# 1                         610    97     13     22  23.727273      0     0
# 2                         407     0      0     65   4.416667      2     0
# 3                         317    46     10     62   6.705882      0  5501
# 4                         318     2      0     75   9.250000      2     0
# ...                       ...   ...    ...    ...        ...    ...   ...
# 1001                      396     0      7     37  14.285714      2  6101
# 1002                      100     4     10     27   9.230769     28  7401
# 1003                      258     0      1     70   5.266667      1  3301
# 1004                      217     0      0     96  11.400000      1  7301
# 1005                      431     0      7     77   7.428571      1  1709
#
#      domain  target_d
# 0        T3      11.0
# 1        S1      45.0
# 2        R3       3.0
# 3        R2       5.0
# 4        T1      10.0
# ...     ...       ...
# 1001     S2      50.0
# 1002     C1      10.0
# 1003     S2       5.0
# 1004     T2      14.0
# 1005     S2       9.0
#
# [2006 rows x 17 columns]

# %%
data = data.drop_duplicates()
data
# Out:
#           id      state gender  ic2  ic3  ic4    ic5  median_home_val  \
# 0     119966         TX      F  264  243  281   9372            321.0
# 1     152470         CA      F  763  698  807  53158           5725.0
# 2      48527         AL   Male  502  439  496  17743            931.0
# 3     171528         CA      F  389  405  471  17431           1895.0
# 4      50122  Tennessee      F  340  352  370  12416            715.0
# ...      ...        ...    ...  ...  ...  ...    ...              ...
# 996    66762         MI      F  336  339  388  12653            632.0
# 997     6443         FL      M  263  262  274  11132            595.0
# 998   151175         CA      F  504  538  537  16165           2707.0
# 999   151504         CA      M  609  612  653  24745           2666.0
# 1000   74303         MI      M  264  269  299  10088            444.0
#
#       median_household_income  hvp1  pobc1  pobc2    avggift  tcode   dob  \
# 0                         225     0      3     68   8.058824      0  3212
# 1                         610    97     13     22  23.727273      0     0
# 2                         407     0      0     65   4.416667      2     0
# 3                         317    46     10     62   6.705882      0  5501
# 4                         318     2      0     75   9.250000      2     0
# ...                       ...   ...    ...    ...        ...    ...   ...
# 996                       279     2      1     71   8.533333      0     0
# 997                       252     0      8     11  14.692308      1  2501
# 998                       507    80     24     54  12.117647      0  4001
# 999                       535    63     22     45  12.333333      1  4401
# 1000                      225     3      1     86  17.142857      4   405
#
#      domain  target_d
# 0        T3      11.0
# 1        S1      45.0
# 2        R3       3.0
# 3        R2       5.0
# 4        T1      10.0
# ...     ...       ...
# 996       0       5.0
# 997      T2      20.0
# 998      U1      22.0
# 999      S1      21.0
# 1000     R2      25.0
#
# [2001 rows x 17 columns]
